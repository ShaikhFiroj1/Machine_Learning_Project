# %%
import os
import pandas as pd

# %%
housing = pd.read_csv("housing.csv")

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt

# %%
housing.hist( figsize=(20,40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000008F15B25668>,
# ...
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing, test_size = 0.2, random_state=42)

# %%
train_set.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16512.000000  16512.000000        16512.000000  16512.000000
# mean    -119.582290     35.643149           28.608285   2642.004784
# std        2.005654      2.136665           12.602499   2174.646744
# min     -124.350000     32.550000            1.000000      2.000000
# 25%     -121.810000     33.930000           18.000000   1454.000000
# 50%     -118.510000     34.260000           29.000000   2129.000000
# 75%     -118.010000     37.720000           37.000000   3160.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    16512.000000  16512.000000  16512.000000   16512.000000
# mean       538.496851   1426.453004    499.986919       3.880754
# std        419.007096   1137.056380    380.967964       1.904294
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing = start_train_set.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7b9f65707e39> in <module>
# ----> 1 housing = start_train_set.copy()
#
# NameError: name 'start_train_set' is not defined

# %%
start_train_set = housing.loc[train_index]

# %%
housing = train_set.copy()

# %%
housing.plot(kind="scatter", x="longitude", y="latitude",alpha="0.1")

# %%
housing.plot(kind="scatter", x="longitude", y="latitude",alpha=0.4,
c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,)
plt.legend()

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
s=housing["population"]/100, label="population", figsize=(10,7),
c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,)
plt.legend()

# %%
corr_matrix = housing.corr()

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)

# %%
housing.plot(kind="scatter", x='population', y='households',alpha=0.4,figsize=(10,8),
c="total_rooms",cmap=plt.get_cmap("jet"),colorbar=True)

# %%
housing.plot(kind="scatter", x="median_income",y="median_house_value",alpha=0.4)

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
#
#        population  households  median_income  median_house_value  \
# 14196      2300.0       623.0         3.2596            103000.0
# 8267       1314.0       756.0         3.8125            382100.0
# 17445       915.0       336.0         4.1563            172600.0
# 14265      1418.0       355.0         1.9425             93400.0
# 2271        874.0       380.0         3.5542             96500.0
#
#       ocean_proximity
# 14196      NEAR OCEAN
# 8267       NEAR OCEAN
# 17445      NEAR OCEAN
# 14265      NEAR OCEAN
# ...

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16512.000000  16512.000000        16512.000000  16512.000000
# mean    -119.582290     35.643149           28.608285   2642.004784
# std        2.005654      2.136665           12.602499   2174.646744
# min     -124.350000     32.550000            1.000000      2.000000
# 25%     -121.810000     33.930000           18.000000   1454.000000
# 50%     -118.510000     34.260000           29.000000   2129.000000
# 75%     -118.010000     37.720000           37.000000   3160.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    16512.000000  16512.000000  16512.000000   16512.000000
# mean       538.496851   1426.453004    499.986919       3.880754
# std        419.007096   1137.056380    380.967964       1.904294
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing.drop(['households','housing_median_age'],axis=1).head()
# Out:
#        longitude  latitude  total_rooms  total_bedrooms  population  \
# 14196    -117.03     32.71       3126.0           627.0      2300.0
# 8267     -118.16     33.77       3382.0           787.0      1314.0
# 17445    -120.48     34.66       1897.0           331.0       915.0
# 14265    -117.11     32.69       1421.0           367.0      1418.0
# 2271     -119.80     36.78       2382.0           431.0       874.0
#
#        median_income  median_house_value ocean_proximity
# 14196         3.2596            103000.0      NEAR OCEAN
# 8267          3.8125            382100.0      NEAR OCEAN
# 17445         4.1563            172600.0      NEAR OCEAN
# 14265         1.9425             93400.0      NEAR OCEAN
# 2271          3.5542             96500.0          INLAND

# %%
pd.value_counts(housing["total_bedrooms"]).plot()

# %%
housing["total_bedrooms"].mean()
# Out:
# 538.4968507751938

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
#
#        population  households  median_income  median_house_value  \
# 14196      2300.0       623.0         3.2596            103000.0
# 8267       1314.0       756.0         3.8125            382100.0
# 17445       915.0       336.0         4.1563            172600.0
# 14265      1418.0       355.0         1.9425             93400.0
# 2271        874.0       380.0         3.5542             96500.0
#
#       ocean_proximity
# 14196      NEAR OCEAN
# 8267       NEAR OCEAN
# 17445      NEAR OCEAN
# 14265      NEAR OCEAN
# ...

# %%
housing.groupby(["ocean_proximity","median_house_value"]).mean()
# Out:
#                                      longitude   latitude  housing_median_age  \
# ocean_proximity median_house_value
# <1H OCEAN       36700.0            -123.850000  41.320000           31.000000
#                 38800.0            -118.280000  34.020000           52.000000
#                 43000.0            -116.990000  33.460000           13.000000
#                 45000.0            -117.900000  33.800000           21.000000
#                 46700.0            -118.080000  33.760000           26.000000
# ...                                        ...        ...                 ...
# NEAR OCEAN      495900.0           -122.270000  37.470000           44.000000
#                 496000.0           -122.260000  37.450000           17.000000
#                 496400.0           -117.250000  32.720000           33.000000
#                 500000.0           -119.680000  35.024286           33.857143
#                 500001.0           -119.755152  35.089879           30.636364
# ...

# %%
housing[housing["median_income"]<3].groupby(["ocean_proximity","median_house_value"]).mean()
# Out:
#                                     longitude  latitude  housing_median_age  \
# ocean_proximity median_house_value
# <1H OCEAN       36700.0             -123.8500   41.3200                31.0
#                 38800.0             -118.2800   34.0200                52.0
#                 43000.0             -116.9900   33.4600                13.0
#                 45000.0             -117.9000   33.8000                21.0
#                 46700.0             -118.0800   33.7600                26.0
# ...                                       ...       ...                 ...
# NEAR OCEAN      420000.0            -121.8200   36.8600                17.0
#                 450000.0            -120.8650   35.8650                26.0
#                 488900.0            -117.2700   32.8500                34.0
#                 500000.0            -117.3800   33.1900                26.0
#                 500001.0            -119.8525   35.0475                17.5
#
# ...

# %%
housing.shape
# Out:
# (16512, 10)

# %%
housing.all
# Out:
# <bound method DataFrame.all of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
# ...

# %%
housing["ocean_proximity"].
# Out:
# <bound method NDFrame.sample of 14196    NEAR OCEAN
# 8267     NEAR OCEAN
# 17445    NEAR OCEAN
# 14265    NEAR OCEAN
# 2271         INLAND
#             ...
# 11284     <1H OCEAN
# 11964        INLAND
# 5390      <1H OCEAN
# 860       <1H OCEAN
# 15795      NEAR BAY
# Name: ocean_proximity, Length: 16512, dtype: object>

# %% [markdown]
# It is pet project to determine house prices near ocean and people who can afford it.
